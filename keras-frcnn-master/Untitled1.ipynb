# %%
import pandas as pd

# %%
dataset = pd.read_csv(r'')
print(dataset.head())

# %%
import Image
imageFile = r"C:\Users\Ab215tx\Desktop\frame1.jpg"
im1 = Image.open(imageFile)
width = 1920
height = 1080
im2 = im1.resize((width, height))
ext = ".jpg"
im2.save("NEAREST" + ext)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-41-9ede7b66ca6b> in <module>()
# ----> 1 import Image
#       2 imageFile = r"C:\Users\Ab215tx\Desktop\frame1.jpg"
#       3 im1 = Image.open(imageFile)
#       4 width = 1920
#       5 height = 1080
#
# ModuleNotFoundError: No module named 'Image'

# %%
'''
import cv2
flename = r'C:\Users\Ab215tx\Desktop\frame1.jpg'
W = 1000
oriimg = cv2.imread(filename,cv2.CV_LOAD_IMAGE_COLOR)
height, width, depth = oriimg.shape
imgScale = W/width
newX,newY = oriimg.shape[1]*imgScale, oriimg.shape[0]*imgScale
newimg = cv2.resize(oriimg,(int(newX),int(newY)))
cv2.imshow("Show by CV2",newimg)
cv2.waitKey(0)
cv2.imwrite("resizeimg.jpg",newimg) 
'''
# Out:
#   File "<ipython-input-59-60e260552888>", line 13
#     '''
#       ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 26-27: truncated \UXXXXXXXX escape

# %%
from PIL import Image, ImageOps
for i in range(525): 
    file_path = r'C:\Users\Ab215tx\Desktop\keras-frcnn-master\data\frame'+str(i)+'.jpg'
    original_image = Image.open(file_path)
    size = (1920, 1080)
    fit_and_resized_image = ImageOps.fit(original_image, size, Image.ANTIALIAS)
    ext = ".jpg"
    save_path = r'C:\Users\Ab215tx\Desktop\keras-frcnn-master\datanew\frame'+str(i)+'.jpg'
    fit_and_resized_image.save(save_path)

# %%
# importing required libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import patches

fig = plt.figure()

#add axes to the image
ax = fig.add_axes([0,0,1,1])

# read and plot the image
image = plt.imread(r'C:\Users\Ab215tx\Desktop\frame0.jpg')
plt.imshow(image)

# iterating over the image for different objects
x = 1253
y = 533
width = 63
height = 129
    
edgecolor = 'r'
rect = patches.Rectangle((x,y), width, height, edgecolor = edgecolor, facecolor = 'none')
ax.add_patch(rect)
